# %% [markdown]
# <a href="https://colab.research.google.com/github/warsztatyandan/eksploracja-danych/blob/master/Drug_consumption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data description: ** https://archive.ics.uci.edu/ml/datasets/Drug+consumption+%28quantified%29
#
# **GitHub repo: **  https://github.com/warsztatyandan/eksploracja-danych
#
# ---
# Warnings and comments:
#
# *   attr. 27 about LSD - there might be a mistake in description ('alcohol', while alcohol was described earlier). I have changed it to LSD anyway
# ---
# It is **HIGHLY RECOMMENDED** to do back-ups of this notebook :)
# Please firstly** SAVE** (!) the file and then download .ipynb and .py versions of this notebook.

# %%
#@title Default title text
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
all_columns = [
    'ID', 
    'Age', 
    'Gender', 
    'Education', 
    'Country',
    'Ethnicity',
    'Neuroticism',
    'Extraversion',
    'Openness to experience',
    'Agreeableness',
    'Conscientiousness',
    'Impulsiveness',
    'Sensation seeing',
    'Alcohol consumption',
    'Amphetamines consumption',
    'Amyl nitrite consumption',
    'Benzodiazepine consumption',
    'Caffeine consumption',
    'Cannabis consumption',
    'Chocolate consumption',
    'Cocaine consumption',
    'Crack consumption',
    'Ecstasy consumption',
    'Heroin consumption',
    'Ketamine consumption',
    'Legal highs consumption',
    'Lysergic acid diethylamide consumption',
    'Methadone consumption',
    'Magic mushrooms consumption',
    'Nicotine consumption',
    'Fictitious drug Semeron consumption',
    'Volatile substance abuse consumption'
]
data = pd.read_csv('drug_consumption.data', header=None, names=all_columns)
data.shape
# Out:
# (1885, 32)

# %%
data.head(10)
# Out:
#    ID      Age   Gender  Education  Country  Ethnicity  Neuroticism  \
# 0   1  0.49788  0.48246   -0.05921  0.96082    0.12600      0.31287
# 1   2 -0.07854 -0.48246    1.98437  0.96082   -0.31685     -0.67825
# 2   3  0.49788 -0.48246   -0.05921  0.96082   -0.31685     -0.46725
# 3   4 -0.95197  0.48246    1.16365  0.96082   -0.31685     -0.14882
# 4   5  0.49788  0.48246    1.98437  0.96082   -0.31685      0.73545
# 5   6  2.59171  0.48246   -1.22751  0.24923   -0.31685     -0.67825
# 6   7  1.09449 -0.48246    1.16365 -0.57009   -0.31685     -0.46725
# 7   8  0.49788 -0.48246   -1.73790  0.96082   -0.31685     -1.32828
# 8   9  0.49788  0.48246   -0.05921  0.24923   -0.31685      0.62967
# 9  10  1.82213 -0.48246    1.16365  0.96082   -0.31685     -0.24649
#
#    Extraversion  Openness to experience  Agreeableness  \
# 0      -0.57545                -0.58331       -0.91699
# 1       1.93886                 1.43533        0.76096
# ...

# %%
data.describe()
# Out:
#                 ID         Age       Gender    Education      Country  \
# count  1885.000000  1885.00000  1885.000000  1885.000000  1885.000000
# mean    945.294960     0.03461    -0.000256    -0.003806     0.355542
# std     545.167641     0.87836     0.482588     0.950078     0.700335
# min       1.000000    -0.95197    -0.482460    -2.435910    -0.570090
# 25%     474.000000    -0.95197    -0.482460    -0.611130    -0.570090
# 50%     946.000000    -0.07854    -0.482460    -0.059210     0.960820
# 75%    1417.000000     0.49788     0.482460     0.454680     0.960820
# max    1888.000000     2.59171     0.482460     1.984370     0.960820
#
#          Ethnicity  Neuroticism  Extraversion  Openness to experience  \
# count  1885.000000  1885.000000   1885.000000             1885.000000
# mean     -0.309577     0.000047     -0.000163               -0.000534
# std       0.166226     0.998106      0.997448                0.996229
# ...

# %%
data['New column'] = data['ID']
data.head()
# Out:
#    ID      Age   Gender  Education  Country  Ethnicity  Neuroticism  \
# 0   1  0.49788  0.48246   -0.05921  0.96082    0.12600      0.31287
# 1   2 -0.07854 -0.48246    1.98437  0.96082   -0.31685     -0.67825
# 2   3  0.49788 -0.48246   -0.05921  0.96082   -0.31685     -0.46725
# 3   4 -0.95197  0.48246    1.16365  0.96082   -0.31685     -0.14882
# 4   5  0.49788  0.48246    1.98437  0.96082   -0.31685      0.73545
#
#    Extraversion  Openness to experience  Agreeableness    ...      \
# 0      -0.57545                -0.58331       -0.91699    ...
# 1       1.93886                 1.43533        0.76096    ...
# 2       0.80523                -0.84732       -1.62090    ...
# 3      -0.80615                -0.01928        0.59042    ...
# 4      -1.63340                -0.45174       -0.30172    ...
#
#    Heroin consumption  Ketamine consumption  Legal highs consumption  \
# 0                 CL0                   CL0                      CL0
# ...

# %%
data['Agreeableness'].unique()
# Out:
# array([-0.91699,  0.76096, -1.6209 ,  0.59042, -0.30172,  2.03972,
#        -0.76096, -1.92595,  0.94156, -0.60633, -1.07533,  0.28783,
#        -0.45321,  1.61108,  1.11406, -0.01729, -1.47955,  0.43852,
#         1.2861 , -2.90161,  0.13136, -2.07848,  1.81866, -0.15487,
#        -1.21213, -1.34289,  1.45039, -1.772  ,  2.46262,  2.23427,
#        -2.35413, -2.70172, -2.21844,  2.75696, -2.5383 ,  3.15735,
#        -2.78793, -3.00537, -3.46436, -3.15735,  3.46436])

# %%
len(data['Agreeableness'].unique())
# Out:
# 41
